# %%
#This is a project that data cleans WHO health statistics
# Out:
# Running cells with 'venv (3.12.3) (Python 3.12.3)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/home/anokye-j-a-ferguson/Desktop/github/tree-ai/venv/bin/python -m pip install ipykernel -U --force-reinstall'

# %%
import pandas as pd

# %%
pdf = pd.read_
